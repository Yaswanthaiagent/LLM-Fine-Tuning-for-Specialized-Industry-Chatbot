# %% [markdown]
# <a href="https://colab.research.google.com/github/Yaswanthaiagent/LLM-Fine-Tuning-for-Specialized-Industry-Chatbot/blob/main/LLM_Fine_Tuning_for_Specialized_Industry_Chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
